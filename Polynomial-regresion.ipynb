# %%
import numpy as np
import pandas as pd
# from sklearn.SimpleImputer import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

dataset = pd.read_csv('Polynomial-Regression-data.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].str.replace(",","").astype(dtype=int).values

y.dtype
# Out:
# dtype('int64')

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
poly_regressor = LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regressor = PolynomialFeatures(degree = 10)

x_poly = poly_regressor.fit_transform(x)

poly = LinearRegression()

poly.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color = 'red')
plt.plot(x,linear_regressor.predict(x),color = 'blue')
plt.show()

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x,poly.predict(poly_regressor.fit_transform(x)),color = 'blue')
plt.show()

# %% [markdown]
# More detailed x-axis

# %%
x_axis = np.arange(min(x) , max(x) , 0.1)
x_axis = x_axis.reshape((len(x_axis),1))

plt.scatter(x,y,color = 'red')
plt.plot(x_axis,poly.predict(poly_regressor.fit_transform(x_axis)),color = 'blue')
plt.title("poly-regression model saliry experince")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show()
# Out:
# <ipython-input-62-d4daaa186fc8>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_axis = np.arange(min(x) , max(x) , 0.1)

# %%
linear_regressor.predict([[6.5]])
# Out:
# array([330378.78787879])
